# %% [markdown]
# # 🛒 Olist E-Commerce Data Cleaning
#
# ### 👨‍💻 Analyst
# **Prakrit Kumar** | Data Analyst
#
# ### 🛠️ Tools
# - Pandas
# - NumPy
# - Matplotlib
# - Seaborn
#
# ### 🎯 Objective
# Clean and prepare the Olist E-Commerce dataset for SQL analysis and Power BI dashboard development.
#
# ### 📋 Tasks
# - Handle missing values
# - Remove duplicates
# - Fix data types
# - Check data quality
# - Prepare data for analysis
#
# ### Date
# - start[ 01-06-2026 ] <> [ 04-06-2026 ]
#
# #### Kaggle Data Link :- https://www.kaggle.com/datasets/olistbr/brazilian-ecommerce

# %% [markdown]
# # Import all Library...!!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Import All DataSet...!!

# %%
customers_df = pd.read_csv("Data/customers.csv")
orders_df = pd.read_csv("Data/orders.csv")
products_df = pd.read_csv("Data/products.csv")
payments_df = pd.read_csv("Data/order_payments.csv")
reviews_df = pd.read_csv("Data/reviews.csv")
sellers_df = pd.read_csv("Data/sellers.csv")
order_items_df = pd.read_csv("Data/order_items.csv")

# %% [markdown]
# ## Clening Start....

# %% [markdown]
# # 1. Customers_df Table cleaning

# %% [markdown]
# #### Data Check

# %%
customers_df.head()

# %% [markdown]
# #### information Check

# %%
customers_df.info()

# %% [markdown]
# #### Sum Null Values

# %%
customers_df.isna().sum()

# %% [markdown]
# #### sum Duplicated values

# %%
customers_df.duplicated().sum()

# %% [markdown]
# #### Check Shape Of The Data

# %%
customers_df.shape

# %% [markdown]
# #### Check Columns Name

# %%
customers_df.columns

# %% [markdown]
# ### Data Check Complete

# %% [markdown]
# ### All informations about customer_df
# - All Data type is correct.
# - No Null Values.
# - No duplicated Values.
# - Data shape(99441,5).
# - i thought **customer_zip_code_prefix** is not needed fou us so we drop it.

# %% [markdown]
# #### Drop **Customer_zip_code_prifix**

# %%
customers_df=customers_df.drop("customer_zip_code_prefix",axis=1)

# %% [markdown]
# #### Chek Columns

# %%
customers_df.columns

# %% [markdown]
# ## Customer_df is complete...!!

# %% [markdown]
# ### **next table start**

# %% [markdown]
# # 2. Order_df Table Cleaning

# %% [markdown]
# #### Data Check

# %%
orders_df.head()

# %% [markdown]
# #### Information Check

# %%
orders_df.info()

# %% [markdown]
# #### Sum Null Values

# %%
orders_df.isna().sum()

# %% [markdown]
# #### Sum Duplicated Values

# %%
orders_df.duplicated().sum()

# %% [markdown]
# #### check Shape of The Data

# %%
orders_df.shape

# %% [markdown]
# #### Check Columns

# %%
orders_df.columns

# %% [markdown]
# ### Data Check Complet

# %% [markdown]
# ### all information about orders_df.
# #### Wrong data type
# - order_purchase_timestamp
# - order_approved_at
# - order_delivered_carrier_date
# - order_delivered_customer_date
# - order_estimated_delivery_date
# - **conver into object to datetime**
# #### Null values
# - order_approved_at =160
# - order_delivered_carrier_date =1783
# - order_delivered_customer_date =2965
# #### No duplicate values
# #### drop column that column is not needed for us
# - order_approved_at
# - order_delivered_carrier_date

# %% [markdown]
# ## First drop unwantade clumns

# %%
orders_df=orders_df.drop(["order_approved_at","order_delivered_carrier_date"],axis=1)

# %% [markdown]
# ##### Check again columnname

# %%
orders_df.columns

# %% [markdown]
# ## Correct Datatype

# %%
orders_df["order_purchase_timestamp"]=pd.to_datetime(orders_df["order_purchase_timestamp"])

# %%
orders_df["order_delivered_customer_date"]=pd.to_datetime(orders_df["order_delivered_customer_date"])

# %%
orders_df["order_estimated_delivery_date"]=pd.to_datetime(orders_df["order_estimated_delivery_date"])

# %% [markdown]
# ##### Check again information

# %%
orders_df.info()

# %% [markdown]
# #### Check null values

# %%
orders_df.isna().sum()

# %%
orders_df['order_status'].value_counts()

# %% [markdown]
# #### **i don't fill null values beacuse some reson**
# - order_delivered_customer_date has 2,965 null values.
# - were canceled, unavailable, shipped, or not yet delivered.
# - Since no actual delivery happened, a delivery date cannot exist.

# %% [markdown]
# ## Order_df is complete

# %% [markdown]
# ### **next table start**

# %% [markdown]
# # 3. Products_df Table Cleaning

# %% [markdown]
# #### Data Check

# %%
products_df.head()

# %% [markdown]
# #### Information Chek

# %%
products_df.info()

# %% [markdown]
# #### Sum Null Values

# %%
products_df.isna().sum()

# %% [markdown]
# #### Sum Duplicated Values

# %%
products_df.duplicated().sum()

# %% [markdown]
# ##### Check Shape of The Data

# %%
products_df.shape

# %% [markdown]
# ## Data check complete

# %% [markdown]
# ### all information about Products_df.
# #### Data type correct
# #### Null values
# - product_category_name = 610
# - product_category_name = 610
# - product_name_lenght = 610
# - product_description_lenght = 610
# - product_photos_qty = 610
# - product_weight_g = 2
# - product_length_cm = 2
# - product_height_cm = 2
# - product_width_cm = 2
# #### No duplicate values
# #### drop column that column is not neded for us
# - product_name_lenght
# - product_description_lenght
# - product_photos_qty
# - product_weight_g
# - product_length_cm
# - product_height_cm
# - product_width_cm
# #### fill
# - null category name fill **unknow** (610)

# %% [markdown]
# ### First drop columns wich columns is not important for our analysis

# %%
products_df=products_df.drop(
    [
        "product_name_lenght" ,        
        "product_description_lenght" ,   
        "product_photos_qty" ,           
        "product_weight_g" ,               
        "product_length_cm" ,             
        "product_height_cm" ,              
        "product_width_cm"
    ],
        axis=1
)

# %% [markdown]
# #### Check columns

# %%
products_df.isna().sum()

# %% [markdown]
# ##### find the persentage of null value in category

# %%
products_df.shape

# %%
610/32951

# %% [markdown]
# ###### onlu 0.18 % name is mising so we fill **unknow**

# %%
products_df["product_category_name"]=products_df["product_category_name"].fillna("unknow")

# %% [markdown]
# ##### Check

# %%
products_df.isna().sum()

# %%
products_df["product_category_name"].unique()

# %%
print("total numer of category = ",products_df["product_category_name"].nunique())

# %% [markdown]
# ## products_df is complet

# %% [markdown]
# ### **next table start**

# %% [markdown]
# # 4. Payments_df Table Cleaning

# %% [markdown]
# #### Data Check

# %%
payments_df.head()

# %% [markdown]
# #### Information Check

# %%
payments_df.info()

# %% [markdown]
# #### Sum Null Values

# %%
payments_df.isna().sum()

# %% [markdown]
# #### Chek Statstics

# %%
payments_df.describe()

# %% [markdown]
# #### Sum Duplicated Values

# %%
payments_df.duplicated().sum()

# %% [markdown]
# #### Check Shape of The Data

# %%
payments_df.shape

# %% [markdown]
# ## Data check complete

# %% [markdown]
# ### All informations about Payments_df
# - All Data type is correct.
# - No Null Values.
# - statstics is ok
# - No duplicated Values.
# - Data shape(103886,5).
# - i thought **paynent_sequential** is not needed fou us so we drop it.

# %% [markdown]
# ### drop column this is not usefull

# %%
payments_df=payments_df.drop("payment_sequential",axis=1)

# %% [markdown]
# ## paypayments_df is complete

# %% [markdown]
# ### **next table start**

# %% [markdown]
# # 5. Reviews_df Table Cleaning

# %% [markdown]
# #### Data Check

# %%
reviews_df.head()

# %% [markdown]
# #### Information Check

# %%
reviews_df.info()

# %% [markdown]
# #### Sum NUll Values

# %%
reviews_df.isna().sum()

# %% [markdown]
# #### Check Statstics

# %%
reviews_df.describe()

# %% [markdown]
# #### Sum Duplicated Values

# %%
reviews_df.duplicated().sum()

# %% [markdown]
# #### Check Shape of The Data

# %%
reviews_df.shape

# %% [markdown]
# ### Data check cpmplete

# %% [markdown]
# ## All information about reviews table
# - data type is correct
# - no duplicated value
# - statstics is ok
# - null values present in
#     - review_comment_title = 87656
#     - review_comment_message = 58247
# - drop columns
#     - review_comment_title
#     - review_comment_message
#     - review_creation_date
#     - review_answer_timestamp
#     -  **beacuse this column is not needed for analysis**

# %% [markdown]
# ## drop columns

# %%
reviews_df=reviews_df.drop(
    [
       "review_comment_title",
       "review_comment_message",
       "review_creation_date",
       "review_answer_timestamp" 
    ],
       axis=1
)

# %% [markdown]
# #### check Null values

# %%
reviews_df.isna().sum()

# %% [markdown]
# ## review_df is completed

# %% [markdown]
# ### **next table start**

# %% [markdown]
# # 6. Sellers_df Table Cleaning

# %% [markdown]
# #### Data Check

# %%
sellers_df.head()

# %% [markdown]
# #### Information Check

# %%
sellers_df.info()

# %% [markdown]
# #### Sum NUll Values

# %%
sellers_df.isna().sum()

# %% [markdown]
# #### Sum Duplicated Values

# %%
sellers_df.duplicated().sum()

# %% [markdown]
# #### Check Shape of The Data

# %%
sellers_df.shape

# %% [markdown]
# ## Data check complete

# %% [markdown]
# ## All information about sellers_df
# - data type is correct
# - no null values
# - no duplicated values
# - shape of data (3095,4)
# - drop sone column(**seller_zip_code_prefix**)

# %%
sellers_df=sellers_df.drop("seller_zip_code_prefix",axis=1)

# %% [markdown]
# ## seller_df is completed

# %% [markdown]
# ### **next table start**

# %% [markdown]
# # 7. Order_items_df Table Cleaning

# %% [markdown]
# #### Data Check

# %%
order_items_df.head()

# %% [markdown]
# #### Information Check

# %%
order_items_df.info()

# %% [markdown]
# #### Sum Null Values

# %%
order_items_df.isna().sum()

# %% [markdown]
# ### Chek Statstics

# %%
order_items_df.describe()

# %% [markdown]
# #### Sum Duplicated Values

# %%
order_items_df.duplicated().sum()

# %% [markdown]
# #### Chek Shape of The Data

# %%
order_items_df.shape

# %% [markdown]
# ## Data chek is complete

# %% [markdown]
# ## All information about order_items_df
# - data type is correct
# - no null values
# - no duplicated values
# - statstics is ok
# - shape of data(112650,7)
# - drop one column(**"shipping_limit_date"**)

# %%
order_items_df=order_items_df.drop("shipping_limit_date",axis=1)

# %% [markdown]
# # **All Table Clening Is Completed**

# %% [markdown]
# #### **Save all clene table for future**

# %% [markdown]
# customers_df.to_csv("clean_customer.csv", index=False)
# orders_df.to_csv("clean_order.csv", index=False)
# products_df.to_csv("clean_products.csv", index=False)
# payments_df.to_csv("clean_payments.csv", index=False)
# reviews_df.to_csv("clean_reviews.csv", index=False)
# sellers_df.to_csv("clean_sellers.csv", index=False)
# order_items_df.to_csv("clean_order_items.csv", index=False)

# %% [markdown]
# # **🏰All Table Information or Summary....!!**

# %% [markdown]
# # 1. **All informations about customer_df**
# - All Data type is correct.
# - No Null Values.
# - No duplicated Values.
# - Data shape(99441,5).
# - i thought **customer_zip_code_prefix** is not nedded fou us so we drop it.
# # 2. **all information about orders_df.**
# #### Wrong data type
# - order_purchase_timestamp
# - order_approved_at
# - order_delivered_carrier_date
# - order_delivered_customer_date
# - order_estimated_delivery_date
# - **conver into object to datetime**
# #### Null values
# - order_approved_at =160
# - order_delivered_carrier_date =1783
# - order_delivered_customer_date =2965
# #### No duplicate values
# #### drop column that column is not neded for us
# - order_approved_at
# - order_delivered_carrier_date
# # 3. **all information about Products_df.**
# #### Data type correct
# #### Null values
# - product_category_name = 610
# - product_category_name = 610
# - product_name_lenght = 610
# - product_description_lenght = 610
# - product_photos_qty = 610
# - product_weight_g = 2
# - product_length_cm = 2
# - product_height_cm = 2
# - product_width_cm = 2
# #### No duplicate values
# #### drop column that column is not neded for us
# - product_name_lenght
# - product_description_lenght
# - product_photos_qty
# - product_weight_g
# - product_length_cm
# - product_height_cm
# - product_width_cm
# #### fill
# - null category name fill **unknow** (610)
# # 4. **All informations about Payments_df**
# - All Data type is correct.
# - No Null Values.
# - statstics is ok
# - No duplicated Values.
# - Data shape(103886,5).
# - i thought **paynent_sequential** is not nedded fou us so we drop it.
# # 5. **All information about reviews table**
# - data type is correct
# - no duplicated value
# - statstics is ok
# - null values present in
#     - review_comment_title = 87656
#     - review_comment_message = 58247
# - drop columns
#     - review_comment_title
#     - review_comment_message
#     - review_creation_date
#     - review_answer_timestamp
#     -  **beacuse this column is not neded for analysis**
# # 6. **All information about sellers_df**
# - data type is correct
# - no null values
# - no duplicated values
# - shape of data (3095,4)
# - drop sone column(**seller_zip_code_prefix**)
# # 7. **All information about order_items_df**
# - data type is correct
# - no null values
# - no duplicated values
# - statstics is ok
# - shape of data(112650,7)
# - drop one column(**"shipping_limit_date"**)
# # 8. **All Table Save INto Again To Clened File**
# - customers_df.to_csv("clean_customer.csv", index=False)
# - orders_df.to_csv("clean_order.csv", index=False)
# - products_df.to_csv("clean_products.csv", index=False)
# - payments_df.to_csv("clean_payments.csv", index=False)
# - reviews_df.to_csv("clean_reviews.csv", index=False)
# - sellers_df.to_csv("clean_sellers.csv", index=False)
# - order_items_df.to_csv("clean_order_items.csv", index=False)

# %% [markdown]
# ### 9. **Advance tool used data load direct pandas to postgresql data base and table already created..!!**

# %%
from sqlalchemy import create_engine
engine = create_engine( "postgresql+psycopg2://postgres:4012@localhost:5432/olist_db")
# Database name = olist_db
# port number = 5432
# Username = postgres
# host = localhost

# %%
customers_df.to_sql("customers", engine, if_exists="append", index=False)
print("customers data lodaed")
# Out:
# customers data lodaed

# %%
sellers_df.to_sql("sellers", engine, if_exists="append", index=False)
print("sellers data lodaed")
# Out:
# sellers data lodaed

# %%
products_df.to_sql("product", engine, if_exists="append", index=False)
print("product data loaded")
# Out:
# product data loaded

# %%
orders_df.to_sql("orders", engine, if_exists="append", index=False)
print("order data loaded")
# Out:
# order data loaded

# %%
payments_df.to_sql("payments", engine, if_exists="append", index=False)
print("payments data loaded")
# Out:
# payments data loaded

# %%
reviews_df.to_sql("reviews", engine, if_exists="append", index=False)
print("reviews data loaded")
# Out:
# reviews data loaded

# %%
order_items_df.to_sql("order_items", engine, if_exists="append", index=False)
print("order_items data loaded")
# Out:
# order_items data loaded

# %% [markdown]
# ### **All is ok clening and load data to postgresql**
